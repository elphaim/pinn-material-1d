# %% [markdown]
# # Physics-Informed Neural Network for 1D Heat Equation
#
# ## Problem Setup
# We solve: $\frac{\partial u}{\partial t} = \alpha \frac{\partial^2 u}{\partial x^2}$
#
#  - **Forward Problem**: Given $\alpha$, find $u(x,t)$
#  - **Inverse Problem**: Given measurements of $u$, find $\alpha$

# %%
import torch
import numpy as np

import sys
sys.path.append('..')

from data.heat_data import HeatEquationData
from models.heat_pinn_strategy import StrategicPINN, WeakFormLoss
from training.trainer_strategy import StrategicPINNTrainer
from utils.plotter import plot_solution
from utils.test_functions import generate_compact_gaussians, plot_compact_gaussians

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

print("Imports successful.")
# Out:
# Imports successful.

# %% [markdown]
# ## Generate Data

# %% [markdown]
# ### Base data

# %%
data_gen = HeatEquationData(
    L=1.0,                  # Domain length
    T=1.0,                  # Final time
    alpha=0.01,             # True thermal diffusivity
    N_f=10000,              # Number of collocation points
    N_bc = 100,             # BC points
    N_ic = 200,             # IC points
    N_sensors=10,           # Sensor locations
    N_time_measurements=10, # Time measurements
    noise_level=0.01,       # 1% noise (SNR ~ 40 dB)
    device='cpu'
)

# Generate base dataset
base_data = data_gen.generate_full_dataset()

# Visualize the data
data_gen.visualize_data(base_data)
# Out:
# Data Generator initialized:
#   Domain: x ∈ [0, 1.0], t ∈ [0, 1.0]
#   True alpha: 0.01
#   Collocation points: 10000
#   Boundary points: 100
#   Initial condition points: 200
#   Measurements: 10 sensors × 10 times = 100 total
#   Noise level: 1.0% (SNR ≈ 40 dB)
#
# ============================================================
# Generating complete dataset...
# ============================================================
#
# Measurements generated:
#   Sensor locations: [0.09090909 0.18181818 0.27272727 0.36363636 0.45454545 0.54545455
#  0.63636364 0.72727273 0.81818182 0.90909091]
#   Time points: [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
#   Total measurements: 100
#   Actual SNR: 40.3 dB
#
# Dataset generation complete.

# %% [markdown]
# ### Test functions for weak form

# %%
test_funcs, test_doms = generate_compact_gaussians(
    L=1.0,
    T=1.0,
    n_funcs=50, 
    support_radius=0.15,
    placement='uniform',
    min_separation=0.05,
    smooth=0.0)

print("Test function generation complete.")

plot_compact_gaussians(test_funcs, test_doms)
# Out:
# Uniform Placement: Successfully placed 49/50 test functions on 7×7 grid
# Test function generation complete.

# %% [markdown]
# ### Collect strong- and weak-form data

# %%
strong_data = {
    'x_f': base_data['x_f'],
    't_f': base_data['t_f'],
    'x_bc': base_data['x_bc'],
    't_bc': base_data['t_bc'],
    'u_bc': base_data['u_bc'],
    'x_ic': base_data['x_ic'],
    't_ic': base_data['t_ic'],
    'u_ic': base_data['u_ic'],
    'x_m': base_data['x_m'],
    't_m': base_data['t_m'],
    'u_m': base_data['u_m']
}

# %%
weak_data = {
    'test_funcs': test_funcs,
    'test_doms': test_doms,
    'x_bc': base_data['x_bc'],
    't_bc': base_data['t_bc'],
    'u_bc': base_data['u_bc'],
    'x_ic': base_data['x_ic'],
    't_ic': base_data['t_ic'],
    'u_ic': base_data['u_ic'],
    'x_m': base_data['x_m'],
    't_m': base_data['t_m'],
    'u_m': base_data['u_m']
}

# %% [markdown]
# # Strong-form PINN

# %% [markdown]
# ## Forward Problem

# %%
strong_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)

# %%
strong_trainer_forward = StrategicPINNTrainer(
    model=strong_model_forward,
    data=strong_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

strong_trainer_forward.train(
    epochs=5000,
    print_every=1000,
    plot_every=2500
)
# Out:
# Trainer initialized:
#   Loss strategy: StrongFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.1s)
#   Adam learning rate: 1.00e-03
#   Total: 4.255244e-01
#   Residual: 2.943220e-04 (λ=1.00)
#   Boundary: 1.297725e-02 (λ=1.00)
#   Initial: 4.122528e-01 (λ=1.00)
#
# Epoch 1000/5000 (98.4s)
#   Adam learning rate: 1.00e-03
#   Total: 1.081382e-04
#   Residual: 1.230911e-05 (λ=2.25)
#   Boundary: 2.718386e-05 (λ=0.76)
#   Initial: 7.425269e-05 (λ=0.81)
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# Epoch 2000/5000 (200.7s)
#   Adam learning rate: 5.00e-04
#   Total: 4.958095e-05
#   Residual: 7.647085e-06 (λ=3.04)
#   Boundary: 1.290967e-05 (λ=0.71)
#   Initial: 2.160455e-05 (λ=0.80)
#
# ============================================================
# Switching to L-BFGS at Epoch 2173
#    Reason: Plateau detected (var=0.099993, slope=0.000589)
#    Loss before switch: 4.472202e-05
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 23
#   Loss: 2.375774e-05
#   Improvement: 46.88%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 1.762379e-05
#   Improvement: 60.59%
#
# L-BFGS Step 3/100
#   Internal iterations: 24
#   Loss: 1.385257e-05
#   Improvement: 69.03%
#
# L-BFGS Step 4/100
#   Internal iterations: 22
#   Loss: 1.135618e-05
#   Improvement: 74.61%
#
# L-BFGS Step 5/100
#   Internal iterations: 2
#   Loss: 1.135482e-05
#   Improvement: 74.61%
#
# L-BFGS Step 6/100
#   Internal iterations: 1
#   Loss: 1.135482e-05
#   Improvement: 74.61%
#
# L-BFGS converged (loss change: 1.365197e-09)
#
# Final training plot:
# Training complete. Time: 227.8s

# %%
plot_solution(model=strong_model_forward, data=strong_data, alpha_true=0.01)

# %% [markdown]
# ## Inverse Problem

# %%
strong_model_inverse = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    inverse=True,
    alpha_init=0.02
)
# Out:
# Inverse problem mode: alpha initialized to 0.02
# StrategicPINN initialized with StrongFormLoss (default)

# %%
strong_trainer_inverse = StrategicPINNTrainer(
    model=strong_model_inverse,
    data=strong_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

strong_trainer_inverse.train(
    epochs=5000,
    print_every=1000,
    plot_every=2500
)
# Out:
# Trainer initialized:
#   Loss strategy: StrongFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Inverse
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.1s)
#   Adam learning rate: 1.00e-03
#   Total: 1.520335e+00
#   Residual: 3.129298e-02 (λ=1.00)
#   Boundary: 3.821262e-02 (λ=1.00)
#   Initial: 6.636565e-01 (λ=1.00)
#   Measurement: 7.871733e-01 (λ=1.00)
#   Alpha: 0.019000 (true: 0.01)
#
# Epoch 1000/5000 (103.8s)
#   Adam learning rate: 1.00e-03
#   Total: 9.080961e-04
#   Residual: 6.231871e-05 (λ=4.35)
#   Boundary: 2.323975e-04 (λ=0.52)
#   Initial: 2.112950e-04 (λ=1.24)
#   Measurement: 2.617919e-04 (λ=0.97)
#   Alpha: 0.006982 (true: 0.01)
#
# Epoch 2000/5000 (201.2s)
#   Adam learning rate: 1.00e-03
#   Total: 1.460912e-04
#   Residual: 4.711787e-06 (λ=4.00)
#   Boundary: 4.281982e-05 (λ=0.51)
#   Initial: 3.302380e-05 (λ=1.22)
#   Measurement: 6.417385e-05 (λ=1.01)
#   Alpha: 0.009759 (true: 0.01)
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 2682
#    Reason: Plateau detected (var=0.098902, slope=0.000553)
#    Loss before switch: 1.063175e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 23
#   Loss: 9.326267e-05
#   Improvement: 12.28%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 7.519880e-05
#   Improvement: 29.27%
#
# L-BFGS Step 3/100
#   Internal iterations: 20
#   Loss: 6.643313e-05
#   Improvement: 37.51%
#
# L-BFGS Step 4/100
#   Internal iterations: 1
#   Loss: 6.643313e-05
#   Improvement: 37.51%
#
# L-BFGS Step 5/100
#   Internal iterations: 1
#   Loss: 6.643313e-05
#   Improvement: 37.51%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 275.5s

# %%
plot_solution(model=strong_model_inverse, data=strong_data, alpha_true=0.01)

# %% [markdown]
# # Weak-form PINN

# %% [markdown]
# ## Forward Problem

# %%
weak_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)

# %% [markdown]
# ### Simpson integration

# %%
weak_model_forward.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_forward, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.2s)
#   Adam learning rate: 1.00e-03
#   Total: 8.395649e-01
#   Residual: 1.206724e-05 (λ=1.00)
#   Boundary: 4.115010e-02 (λ=1.00)
#   Initial: 7.984028e-01 (λ=1.00)
#   Non-zero weak residuals: 49
#
# Epoch 1000/5000 (191.3s)
#   Adam learning rate: 1.00e-03
#   Total: 4.112625e-04
#   Residual: 4.430548e-07 (λ=174.57)
#   Boundary: 8.444294e-05 (λ=0.74)
#   Initial: 4.452952e-04 (λ=0.61)
#   Non-zero weak residuals: 49
#
# Epoch 2000/5000 (371.5s)
#   Adam learning rate: 1.00e-03
#   Total: 1.310315e-04
#   Residual: 1.477448e-07 (λ=220.68)
#   Boundary: 2.918599e-05 (λ=0.71)
#   Initial: 1.229188e-04 (λ=0.63)
#   Non-zero weak residuals: 49
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
# ========================================
# Adam LR reduced: 5.00e-04 -> 2.50e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 2631
#    Reason: Plateau detected (var=0.093483, slope=0.000500)
#    Loss before switch: 1.043069e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 22
#   Loss: 7.394496e-05
#   Improvement: 29.11%
#
# L-BFGS Step 2/100
#   Internal iterations: 23
#   Loss: 4.241329e-05
#   Improvement: 59.34%
#
# L-BFGS Step 3/100
#   Internal iterations: 21
#   Loss: 3.144196e-05
#   Improvement: 69.86%
#
# L-BFGS Step 4/100
#   Internal iterations: 24
#   Loss: 2.220663e-05
#   Improvement: 78.71%
#
# L-BFGS Step 5/100
#   Internal iterations: 25
#   Loss: 1.656828e-05
#   Improvement: 84.12%
#
# L-BFGS Step 6/100
#   Internal iterations: 22
#   Loss: 1.405966e-05
#   Improvement: 86.52%
#
# L-BFGS Step 7/100
#   Internal iterations: 25
#   Loss: 1.124902e-05
#   Improvement: 89.22%
#
# L-BFGS Step 8/100
#   Internal iterations: 26
#   Loss: 8.927501e-06
#   Improvement: 91.44%
#
# L-BFGS Step 9/100
#   Internal iterations: 23
#   Loss: 6.630534e-06
#   Improvement: 93.64%
#
# L-BFGS Step 10/100
#   Internal iterations: 22
#   Loss: 4.949920e-06
#   Improvement: 95.25%
#
# L-BFGS Step 11/100
#   Internal iterations: 25
#   Loss: 2.887745e-06
#   Improvement: 97.23%
#
# L-BFGS Step 12/100
#   Internal iterations: 25
#   Loss: 9.624219e-07
#   Improvement: 99.08%
#
# L-BFGS Step 13/100
#   Internal iterations: 21
#   Loss: 8.326065e-07
#   Improvement: 99.20%
#
# L-BFGS Step 14/100
#   Internal iterations: 3
#   Loss: 8.301860e-07
#   Improvement: 99.20%
#
# L-BFGS Step 15/100
#   Internal iterations: 2
#   Loss: 8.293808e-07
#   Improvement: 99.20%
#
# L-BFGS converged (loss change: 3.225621e-09)
#
# Final training plot:
# Training complete. Time: 542.9s

# %%
plot_solution(model=weak_model_forward, data=weak_data, alpha_true=0.01)

# %% [markdown]
# ### Gauss-Legendre integration

# %%
weak_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)

# %%
weak_model_forward.set_loss_strategy(
    WeakFormLoss(
        integration_method='gauss_legendre',
        n_integration_points=15
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_forward, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Weak-form loss strategy:
#   Method: gauss_legendre
#   Points: 15
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.1s)
#   Adam learning rate: 1.00e-03
#   Total: 1.332948e+00
#   Residual: 1.155793e-06 (λ=1.00)
#   Boundary: 2.043923e-01 (λ=1.00)
#   Initial: 1.128554e+00 (λ=1.00)
#   Non-zero weak residuals: 49
#
# Epoch 1000/5000 (140.7s)
#   Adam learning rate: 1.00e-03
#   Total: 1.814159e-04
#   Residual: 2.155581e-07 (λ=228.98)
#   Boundary: 4.219685e-05 (λ=0.67)
#   Initial: 1.560643e-04 (λ=0.66)
#   Non-zero weak residuals: 49
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1756
#    Reason: Plateau detected (var=0.096915, slope=0.000578)
#    Loss before switch: 9.669641e-05
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 22
#   Loss: 7.516626e-05
#   Improvement: 22.27%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 4.614870e-05
#   Improvement: 52.27%
#
# L-BFGS Step 3/100
#   Internal iterations: 21
#   Loss: 3.517463e-05
#   Improvement: 63.62%
#
# L-BFGS Step 4/100
#   Internal iterations: 21
#   Loss: 2.638120e-05
#   Improvement: 72.72%
#
# L-BFGS Step 5/100
#   Internal iterations: 25
#   Loss: 1.307791e-05
#   Improvement: 86.48%
#
# L-BFGS Step 6/100
#   Internal iterations: 25
#   Loss: 9.220406e-06
#   Improvement: 90.46%
#
# L-BFGS Step 7/100
#   Internal iterations: 25
#   Loss: 7.794760e-06
#   Improvement: 91.94%
#
# L-BFGS Step 8/100
#   Internal iterations: 24
#   Loss: 5.527745e-06
#   Improvement: 94.28%
#
# L-BFGS Step 9/100
#   Internal iterations: 23
#   Loss: 4.555255e-06
#   Improvement: 95.29%
#
# L-BFGS Step 10/100
#   Internal iterations: 10
#   Loss: 4.507603e-06
#   Improvement: 95.34%
#
# L-BFGS Step 11/100
#   Internal iterations: 1
#   Loss: 4.507603e-06
#   Improvement: 95.34%
#
# L-BFGS converged (loss change: 4.765183e-08)
#
# Final training plot:
# Training complete. Time: 280.3s

# %%
plot_solution(model=weak_model_forward, data=weak_data, alpha_true=0.01)

# %% [markdown]
# ### Higher order G-L

# %%
weak_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)

# %%
weak_model_forward.set_loss_strategy(
    WeakFormLoss(
        integration_method='gauss_legendre',
        n_integration_points=25
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_forward, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Weak-form loss strategy:
#   Method: gauss_legendre
#   Points: 25
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.2s)
#   Adam learning rate: 1.00e-03
#   Total: 5.598711e-01
#   Residual: 8.140120e-05 (λ=1.00)
#   Boundary: 2.705480e-02 (λ=1.00)
#   Initial: 5.327349e-01 (λ=1.00)
#   Non-zero weak residuals: 49
#
# Epoch 1000/5000 (196.2s)
#   Adam learning rate: 1.00e-03
#   Total: 2.060014e-04
#   Residual: 1.602421e-07 (λ=439.61)
#   Boundary: 3.497094e-05 (λ=0.62)
#   Initial: 1.582032e-04 (λ=0.72)
#   Non-zero weak residuals: 49
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1649
#    Reason: Plateau detected (var=0.099509, slope=0.000558)
#    Loss before switch: 1.350175e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 22
#   Loss: 5.804325e-05
#   Improvement: 57.01%
#
# L-BFGS Step 2/100
#   Internal iterations: 22
#   Loss: 4.223386e-05
#   Improvement: 68.72%
#
# L-BFGS Step 3/100
#   Internal iterations: 23
#   Loss: 2.554182e-05
#   Improvement: 81.08%
#
# L-BFGS Step 4/100
#   Internal iterations: 24
#   Loss: 2.136723e-05
#   Improvement: 84.17%
#
# L-BFGS Step 5/100
#   Internal iterations: 5
#   Loss: 2.134305e-05
#   Improvement: 84.19%
#
# L-BFGS Step 6/100
#   Internal iterations: 24
#   Loss: 1.895734e-05
#   Improvement: 85.96%
#
# L-BFGS Step 7/100
#   Internal iterations: 7
#   Loss: 1.894309e-05
#   Improvement: 85.97%
#
# L-BFGS Step 8/100
#   Internal iterations: 1
#   Loss: 1.894309e-05
#   Improvement: 85.97%
#
# L-BFGS converged (loss change: 1.425047e-08)
#
# Final training plot:
# Training complete. Time: 350.9s

# %%
plot_solution(model=weak_model_forward, data=weak_data, alpha_true=0.01)

# %% [markdown]
# ## Inverse Problem

# %%
weak_model_inverse = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1], 
    inverse=True,
    alpha_init=0.02,
)
# Out:
# Inverse problem mode: alpha initialized to 0.02
# StrategicPINN initialized with StrongFormLoss (default)

# %% [markdown]
# ### Simpson integration

# %%
weak_model_inverse.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_inverse, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Inverse
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.2s)
#   Adam learning rate: 1.00e-03
#   Total: 1.329186e+00
#   Residual: 1.563872e-05 (λ=1.00)
#   Boundary: 2.009224e-02 (λ=1.00)
#   Initial: 6.131687e-01 (λ=1.00)
#   Measurement: 6.959090e-01 (λ=1.00)
#   Alpha: 0.019001 (true: 0.01)
#   Non-zero weak residuals: 49
#
# Epoch 1000/5000 (182.4s)
#   Adam learning rate: 1.00e-03
#   Total: 5.172248e-04
#   Residual: 1.704903e-07 (λ=548.14)
#   Boundary: 1.226693e-04 (λ=0.50)
#   Initial: 1.468138e-04 (λ=1.19)
#   Measurement: 2.205168e-04 (λ=0.85)
#   Alpha: 0.009809 (true: 0.01)
#   Non-zero weak residuals: 49
#
# Epoch 2000/5000 (366.5s)
#   Adam learning rate: 1.00e-03
#   Total: 3.309154e-04
#   Residual: 8.765563e-08 (λ=672.29)
#   Boundary: 8.222855e-05 (λ=0.52)
#   Initial: 8.991277e-05 (λ=1.11)
#   Measurement: 1.532094e-04 (λ=0.84)
#   Alpha: 0.009890 (true: 0.01)
#   Non-zero weak residuals: 49
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ========================================
# Adam LR reduced: 5.00e-04 -> 2.50e-04
# ========================================
# ============================================================
# Switching to L-BFGS at Epoch 2533
#    Reason: Plateau detected (var=0.092032, slope=0.000539)
#    Loss before switch: 2.005832e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 23
#   Loss: 1.335882e-04
#   Improvement: 33.40%
#
# L-BFGS Step 2/100
#   Internal iterations: 24
#   Loss: 9.462013e-05
#   Improvement: 52.83%
#
# L-BFGS Step 3/100
#   Internal iterations: 22
#   Loss: 7.317132e-05
#   Improvement: 63.52%
#
# L-BFGS Step 4/100
#   Internal iterations: 23
#   Loss: 6.778116e-05
#   Improvement: 66.21%
#
# L-BFGS Step 5/100
#   Internal iterations: 24
#   Loss: 6.268879e-05
#   Improvement: 68.75%
#
# L-BFGS Step 6/100
#   Internal iterations: 25
#   Loss: 4.470868e-05
#   Improvement: 77.71%
#
# L-BFGS Step 7/100
#   Internal iterations: 16
#   Loss: 4.210971e-05
#   Improvement: 79.01%
#
# L-BFGS Step 8/100
#   Internal iterations: 1
#   Loss: 4.210971e-05
#   Improvement: 79.01%
#
# L-BFGS Step 9/100
#   Internal iterations: 1
#   Loss: 4.210971e-05
#   Improvement: 79.01%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 494.9s

# %%
plot_solution(model=weak_model_inverse, data=weak_data, alpha_true=0.01)

# %% [markdown]
# ### Gauss-Legendre integration

# %%
weak_model_inverse = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1], 
    inverse=True,
    alpha_init=0.02,
)
# Out:
# Inverse problem mode: alpha initialized to 0.02
# StrategicPINN initialized with StrongFormLoss (default)

# %%
weak_model_inverse.set_loss_strategy(
    WeakFormLoss(
        integration_method='gauss_legendre',
        n_integration_points=15
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_inverse, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Weak-form loss strategy:
#   Method: gauss_legendre
#   Points: 15
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Inverse
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.2s)
#   Adam learning rate: 1.00e-03
#   Total: 8.048306e-01
#   Residual: 6.070674e-05 (λ=1.00)
#   Boundary: 3.735176e-02 (λ=1.00)
#   Initial: 4.742939e-01 (λ=1.00)
#   Measurement: 2.931242e-01 (λ=1.00)
#   Alpha: 0.019000 (true: 0.01)
#   Non-zero weak residuals: 49
#
# Epoch 1000/5000 (142.5s)
#   Adam learning rate: 1.00e-03
#   Total: 7.983656e-05
#   Residual: 1.440991e-07 (λ=60.72)
#   Boundary: 3.109340e-05 (λ=0.54)
#   Initial: 9.437811e-06 (λ=1.52)
#   Measurement: 5.869798e-05 (λ=0.68)
#   Alpha: 0.010143 (true: 0.01)
#   Non-zero weak residuals: 49
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1752
#    Reason: Plateau detected (var=0.098525, slope=0.000485)
#    Loss before switch: 4.881566e-05
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 21
#   Loss: 4.299962e-05
#   Improvement: 11.91%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 3.746047e-05
#   Improvement: 23.26%
#
# L-BFGS Step 3/100
#   Internal iterations: 23
#   Loss: 3.570271e-05
#   Improvement: 26.86%
#
# L-BFGS Step 4/100
#   Internal iterations: 6
#   Loss: 3.504948e-05
#   Improvement: 28.20%
#
# L-BFGS Step 5/100
#   Internal iterations: 1
#   Loss: 3.504948e-05
#   Improvement: 28.20%
#
# L-BFGS Step 6/100
#   Internal iterations: 1
#   Loss: 3.504948e-05
#   Improvement: 28.20%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 260.5s

# %%
plot_solution(model=weak_model_inverse, data=weak_data, alpha_true=0.01)

# %% [markdown]
# # Weak-form experiments

# %% [markdown]
# ## Test functions distributions

# %% [markdown]
# ### Random

# %%
test_funcs, test_doms = generate_compact_gaussians(
    L=1.0,
    T=1.0,
    n_funcs=50, 
    support_radius=0.15,
    placement='random',
    min_separation=0.05,
    smooth=0.0)

print("Test function generation complete.")

plot_compact_gaussians(test_funcs, test_doms)
# Out:
# Random Placement: Successfully placed 50/50 test functions
# Test function generation complete.

# %%
weak_data = {
    'test_funcs': test_funcs,
    'test_doms': test_doms,
    'x_bc': base_data['x_bc'],
    't_bc': base_data['t_bc'],
    'u_bc': base_data['u_bc'],
    'x_ic': base_data['x_ic'],
    't_ic': base_data['t_ic'],
    'u_ic': base_data['u_ic'],
    'x_m': base_data['x_m'],
    't_m': base_data['t_m'],
    'u_m': base_data['u_m']
}

# %%
weak_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)

weak_model_forward.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_forward, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.3s)
#   Adam learning rate: 1.00e-03
#   Total: 3.774286e-01
#   Residual: 7.608963e-05 (λ=1.00)
#   Boundary: 3.102153e-02 (λ=1.00)
#   Initial: 3.463310e-01 (λ=1.00)
#   Non-zero weak residuals: 50
#
# Epoch 1000/5000 (214.0s)
#   Adam learning rate: 1.00e-03
#   Total: 1.950208e-04
#   Residual: 1.140162e-07 (λ=366.74)
#   Boundary: 5.210514e-05 (λ=0.66)
#   Initial: 1.761232e-04 (λ=0.67)
#   Non-zero weak residuals: 50
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1770
#    Reason: Plateau detected (var=0.099614, slope=0.000582)
#    Loss before switch: 1.016087e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 23
#   Loss: 4.956525e-05
#   Improvement: 51.22%
#
# L-BFGS Step 2/100
#   Internal iterations: 24
#   Loss: 3.638273e-05
#   Improvement: 64.19%
#
# L-BFGS Step 3/100
#   Internal iterations: 23
#   Loss: 2.652982e-05
#   Improvement: 73.89%
#
# L-BFGS Step 4/100
#   Internal iterations: 25
#   Loss: 1.703218e-05
#   Improvement: 83.24%
#
# L-BFGS Step 5/100
#   Internal iterations: 25
#   Loss: 1.528401e-05
#   Improvement: 84.96%
#
# L-BFGS Step 6/100
#   Internal iterations: 27
#   Loss: 1.447929e-05
#   Improvement: 85.75%
#
# L-BFGS Step 7/100
#   Internal iterations: 24
#   Loss: 8.857623e-06
#   Improvement: 91.28%
#
# L-BFGS Step 8/100
#   Internal iterations: 23
#   Loss: 6.873540e-06
#   Improvement: 93.24%
#
# L-BFGS Step 9/100
#   Internal iterations: 25
#   Loss: 3.369428e-06
#   Improvement: 96.68%
#
# L-BFGS Step 10/100
#   Internal iterations: 20
#   Loss: 2.818738e-06
#   Improvement: 97.23%
#
# L-BFGS Step 11/100
#   Internal iterations: 1
#   Loss: 2.818738e-06
#   Improvement: 97.23%
#
# L-BFGS Step 12/100
#   Internal iterations: 1
#   Loss: 2.818738e-06
#   Improvement: 97.23%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 403.0s

# %%
plot_solution(model=weak_model_forward, data=weak_data, alpha_true=0.01)

# %%
weak_model_inverse = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    inverse=True,
    alpha_init=0.02
)

weak_model_inverse.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_inverse, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Inverse problem mode: alpha initialized to 0.02
# StrategicPINN initialized with StrongFormLoss (default)
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Inverse
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.2s)
#   Adam learning rate: 1.00e-03
#   Total: 7.399435e-01
#   Residual: 1.315454e-05 (λ=1.00)
#   Boundary: 3.778163e-02 (λ=1.00)
#   Initial: 3.999352e-01 (λ=1.00)
#   Measurement: 3.022136e-01 (λ=1.00)
#   Alpha: 0.019001 (true: 0.01)
#   Non-zero weak residuals: 50
#
# Epoch 1000/5000 (191.1s)
#   Adam learning rate: 1.00e-03
#   Total: 4.081823e-04
#   Residual: 1.023032e-07 (λ=313.34)
#   Boundary: 1.211985e-04 (λ=0.53)
#   Initial: 1.246381e-04 (λ=1.23)
#   Measurement: 2.073389e-04 (λ=0.76)
#   Alpha: 0.009702 (true: 0.01)
#   Non-zero weak residuals: 50
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1539
#    Reason: Plateau detected (var=0.099993, slope=0.000589)
#    Loss before switch: 2.523635e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 24
#   Loss: 1.253825e-04
#   Improvement: 50.32%
#
# L-BFGS Step 2/100
#   Internal iterations: 22
#   Loss: 1.114738e-04
#   Improvement: 55.83%
#
# L-BFGS Step 3/100
#   Internal iterations: 21
#   Loss: 9.329342e-05
#   Improvement: 63.03%
#
# L-BFGS Step 4/100
#   Internal iterations: 25
#   Loss: 8.499073e-05
#   Improvement: 66.32%
#
# L-BFGS Step 5/100
#   Internal iterations: 22
#   Loss: 7.230547e-05
#   Improvement: 71.35%
#
# L-BFGS Step 6/100
#   Internal iterations: 24
#   Loss: 6.960836e-05
#   Improvement: 72.42%
#
# L-BFGS Step 7/100
#   Internal iterations: 25
#   Loss: 6.734113e-05
#   Improvement: 73.32%
#
# L-BFGS Step 8/100
#   Internal iterations: 25
#   Loss: 5.721421e-05
#   Improvement: 77.33%
#
# L-BFGS Step 9/100
#   Internal iterations: 23
#   Loss: 4.931971e-05
#   Improvement: 80.46%
#
# L-BFGS Step 10/100
#   Internal iterations: 22
#   Loss: 4.780285e-05
#   Improvement: 81.06%
#
# L-BFGS Step 11/100
#   Internal iterations: 25
#   Loss: 4.496436e-05
#   Improvement: 82.18%
#
# L-BFGS Step 12/100
#   Internal iterations: 24
#   Loss: 4.378249e-05
#   Improvement: 82.65%
#
# L-BFGS Step 13/100
#   Internal iterations: 22
#   Loss: 4.329245e-05
#   Improvement: 82.85%
#
# L-BFGS Step 14/100
#   Internal iterations: 25
#   Loss: 4.313839e-05
#   Improvement: 82.91%
#
# L-BFGS Step 15/100
#   Internal iterations: 25
#   Loss: 4.270229e-05
#   Improvement: 83.08%
#
# L-BFGS Step 16/100
#   Internal iterations: 25
#   Loss: 4.188311e-05
#   Improvement: 83.40%
#
# L-BFGS Step 17/100
#   Internal iterations: 25
#   Loss: 4.069802e-05
#   Improvement: 83.87%
#
# L-BFGS Step 18/100
#   Internal iterations: 24
#   Loss: 3.989115e-05
#   Improvement: 84.19%
#
# L-BFGS Step 19/100
#   Internal iterations: 12
#   Loss: 3.974407e-05
#   Improvement: 84.25%
#
# L-BFGS Step 20/100
#   Internal iterations: 1
#   Loss: 3.974407e-05
#   Improvement: 84.25%
#
# L-BFGS Step 21/100
#   Internal iterations: 1
#   Loss: 3.974407e-05
#   Improvement: 84.25%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 380.3s

# %%
plot_solution(model=weak_model_inverse, data=weak_data, alpha_true=0.01)

# %% [markdown]
# ### Boundary

# %%
test_funcs, test_doms = generate_compact_gaussians(
    L=1.0,
    T=1.0,
    n_funcs=50, 
    support_radius=0.15,
    placement='boundary',
    min_separation=0.05,
    smooth=0.0)

print("Test function generation complete.")

plot_compact_gaussians(test_funcs, test_doms)
# Out:
# Boundary Placement: Placed 36 test functions (40% near boundaries)
# Test function generation complete.

# %%
weak_data = {
    'test_funcs': test_funcs,
    'test_doms': test_doms,
    'x_bc': base_data['x_bc'],
    't_bc': base_data['t_bc'],
    'u_bc': base_data['u_bc'],
    'x_ic': base_data['x_ic'],
    't_ic': base_data['t_ic'],
    'u_ic': base_data['u_ic'],
    'x_m': base_data['x_m'],
    't_m': base_data['t_m'],
    'u_m': base_data['u_m']
}

# %%
weak_model_forward = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    alpha_true=0.01, 
    inverse=False
)

weak_model_forward.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_forward, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Forward problem mode: alpha fixed to 0.01
# StrategicPINN initialized with StrongFormLoss (default)
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Forward
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.1s)
#   Adam learning rate: 1.00e-03
#   Total: 4.982250e-01
#   Residual: 1.035117e-06 (λ=1.00)
#   Boundary: 5.057773e-04 (λ=1.00)
#   Initial: 4.977182e-01 (λ=1.00)
#   Non-zero weak residuals: 36
#
# Epoch 1000/5000 (131.2s)
#   Adam learning rate: 1.00e-03
#   Total: 1.603937e-04
#   Residual: 2.473287e-07 (λ=148.26)
#   Boundary: 4.510791e-05 (λ=0.70)
#   Initial: 1.442351e-04 (λ=0.64)
#   Non-zero weak residuals: 36
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1874
#    Reason: Plateau detected (var=0.098738, slope=0.000587)
#    Loss before switch: 7.244929e-05
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 21
#   Loss: 3.967964e-05
#   Improvement: 45.23%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 3.043275e-05
#   Improvement: 57.99%
#
# L-BFGS Step 3/100
#   Internal iterations: 24
#   Loss: 1.047218e-05
#   Improvement: 85.55%
#
# L-BFGS Step 4/100
#   Internal iterations: 24
#   Loss: 8.319446e-06
#   Improvement: 88.52%
#
# L-BFGS Step 5/100
#   Internal iterations: 24
#   Loss: 3.445191e-06
#   Improvement: 95.24%
#
# L-BFGS Step 6/100
#   Internal iterations: 16
#   Loss: 2.312747e-06
#   Improvement: 96.81%
#
# L-BFGS Step 7/100
#   Internal iterations: 1
#   Loss: 2.312747e-06
#   Improvement: 96.81%
#
# L-BFGS Step 8/100
#   Internal iterations: 1
#   Loss: 2.312747e-06
#   Improvement: 96.81%
#
# L-BFGS converged (loss change: 0.000000e+00)
#
# Final training plot:
# Training complete. Time: 264.3s

# %%
plot_solution(model=weak_model_forward, data=weak_data, alpha_true=0.01)

# %%
weak_model_inverse = StrategicPINN(
    layers=[2, 50, 50, 50, 50, 1],
    inverse=True,
    alpha_init=0.02
)

weak_model_inverse.set_loss_strategy(
    WeakFormLoss(
        integration_method='simpson',
        n_integration_points=21
    )
)

trainer_weak = StrategicPINNTrainer(
    model=weak_model_inverse, 
    data=weak_data,
    learning_rate=1e-3,
    switch_var=0.1,
    switch_slope=0.001,
    track_gradient_norms=False,
    adaptive_weights=True,
)

trainer_weak.train(
    epochs=5000, 
    print_every=1000, 
    plot_every=2500)
# Out:
# Inverse problem mode: alpha initialized to 0.02
# StrategicPINN initialized with StrongFormLoss (default)
# Weak-form loss strategy:
#   Method: simpson
#   Points: 21
# Loss strategy changed to WeakFormLoss
# Trainer initialized:
#   Loss strategy: WeakFormLoss
#   Adam LR: 0.001
#   Switch criteria: var < 0.1, |slope| < 0.001
#   L-BFGS max iter: 20
#   Tracking gradient L2 norms: False
#   Adaptive weights: True
#   EMA smoothing: 0.9
#   Update frequency: every 100 epochs
#   Problem type: Inverse
#
# ============================================================
# Starting training...
# ============================================================
#
# Epoch 0/5000 (0.1s)
#   Adam learning rate: 1.00e-03
#   Total: 1.201656e+00
#   Residual: 9.473161e-06 (λ=1.00)
#   Boundary: 8.954356e-03 (λ=1.00)
#   Initial: 5.675276e-01 (λ=1.00)
#   Measurement: 6.251643e-01 (λ=1.00)
#   Alpha: 0.020988 (true: 0.01)
#   Non-zero weak residuals: 36
#
# Epoch 1000/5000 (134.4s)
#   Adam learning rate: 1.00e-03
#   Total: 3.741487e-04
#   Residual: 8.562897e-08 (λ=1084.49)
#   Boundary: 6.579569e-05 (λ=0.52)
#   Initial: 9.285994e-05 (λ=1.41)
#   Measurement: 1.575523e-04 (λ=0.74)
#   Alpha: 0.009709 (true: 0.01)
#   Non-zero weak residuals: 36
#
# ========================================
# Adam LR reduced: 1.00e-03 -> 5.00e-04
# ========================================
#
# ============================================================
# Switching to L-BFGS at Epoch 1863
#    Reason: Plateau detected (var=0.099722, slope=0.000535)
#    Loss before switch: 2.072284e-04
# ============================================================
#
# L-BFGS Step 1/100
#   Internal iterations: 22
#   Loss: 1.214048e-04
#   Improvement: 41.41%
#
# L-BFGS Step 2/100
#   Internal iterations: 21
#   Loss: 1.110130e-04
#   Improvement: 46.43%
#
# L-BFGS Step 3/100
#   Internal iterations: 25
#   Loss: 8.490420e-05
#   Improvement: 59.03%
#
# L-BFGS Step 4/100
#   Internal iterations: 23
#   Loss: 8.061830e-05
#   Improvement: 61.10%
#
# L-BFGS Step 5/100
#   Internal iterations: 23
#   Loss: 7.487323e-05
#   Improvement: 63.87%
#
# L-BFGS Step 6/100
#   Internal iterations: 25
#   Loss: 6.683309e-05
#   Improvement: 67.75%
#
# L-BFGS Step 7/100
#   Internal iterations: 23
#   Loss: 6.513585e-05
#   Improvement: 68.57%
#
# L-BFGS Step 8/100
#   Internal iterations: 25
#   Loss: 5.371845e-05
#   Improvement: 74.08%
#
# L-BFGS Step 9/100
#   Internal iterations: 24
#   Loss: 4.946293e-05
#   Improvement: 76.13%
#
# L-BFGS Step 10/100
#   Internal iterations: 23
#   Loss: 4.908893e-05
#   Improvement: 76.31%
#
# L-BFGS Step 11/100
#   Internal iterations: 25
#   Loss: 4.859034e-05
#   Improvement: 76.55%
#
# L-BFGS Step 12/100
#   Internal iterations: 26
#   Loss: 4.736408e-05
#   Improvement: 77.14%
#
# L-BFGS Step 13/100
#   Internal iterations: 24
#   Loss: 4.665677e-05
#   Improvement: 77.49%
#
# L-BFGS Step 14/100
#   Internal iterations: 25
#   Loss: 4.443948e-05
#   Improvement: 78.56%
#
# L-BFGS Step 15/100
#   Internal iterations: 24
#   Loss: 4.319738e-05
#   Improvement: 79.15%
#
# L-BFGS Step 16/100
#   Internal iterations: 20
#   Loss: 4.303873e-05
#   Improvement: 79.23%
#
# L-BFGS Step 17/100
#   Internal iterations: 25
#   Loss: 4.245611e-05
#   Improvement: 79.51%
#
# L-BFGS Step 18/100
#   Internal iterations: 24
#   Loss: 4.183139e-05
#   Improvement: 79.81%
#
# L-BFGS Step 19/100
#   Internal iterations: 26
#   Loss: 4.114155e-05
#   Improvement: 80.15%
#
# L-BFGS Step 20/100
#   Internal iterations: 25
#   Loss: 4.014480e-05
#   Improvement: 80.63%
#
# L-BFGS Step 21/100
#   Internal iterations: 23
#   Loss: 3.936567e-05
#   Improvement: 81.00%
#
# L-BFGS Step 22/100
#   Internal iterations: 23
#   Loss: 3.913799e-05
#   Improvement: 81.11%
#
# L-BFGS Step 23/100
#   Internal iterations: 25
#   Loss: 3.769516e-05
#   Improvement: 81.81%
#
# L-BFGS Step 24/100
#   Internal iterations: 25
#   Loss: 3.722064e-05
#   Improvement: 82.04%
#
# L-BFGS Step 25/100
#   Internal iterations: 13
#   Loss: 3.712647e-05
#   Improvement: 82.08%
#
# L-BFGS Step 26/100
#   Internal iterations: 2
#   Loss: 3.712553e-05
#   Improvement: 82.08%
#
# L-BFGS converged (loss change: 9.510708e-08)
#
# Final training plot:
# Training complete. Time: 333.7s

# %%
plot_solution(model=weak_model_inverse, data=weak_data, alpha_true=0.01)
